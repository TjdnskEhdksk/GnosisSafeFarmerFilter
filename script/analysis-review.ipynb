# %%
import pickle 

with open('../static/networks/distributeGraph.pkl', 'rb') as f:
    distributeGraph = pickle.load(f)
    print(distributeGraph.number_of_nodes(), distributeGraph.number_of_edges()) # 588150 709997
with open('../static/networks/safeGraph_noUnpopular.pkl', 'rb') as f:
    safeGraph = pickle.load(f)
    print(safeGraph.number_of_nodes(), safeGraph.number_of_edges()) # 55717 915478
# Out:
# 588150 709997
# 48778 621494

# %%
def removeEdgeByTypes(typeNames):
    for edge in safeGraph.edges():
        edgeType = safeGraph.edges[edge]
        for typeName in typeNames:
            if edgeType[typeName] and sum([edgeType['transfer'], edgeType['creator'], edgeType['distributeEth'], edgeType['same_owner'], edgeType['similar_owner']]) == 1:
                safeGraph.remove_edge(edge[0], edge[1])

# a <-- 'creator', 'similar_owner', 'same_owner', 'transfer', 'distributeEth' --> b
# a <-- 'creator' = True, 'similar_owner' = False, 'same_owner' = False, 'transfer' = False, 'distributeEth' = False --> b
# a <-- 'creator' = False, 'similar_owner' = False, 'same_owner' = False, 'transfer' = True, 'distributeEth' = False --> b

removeEdgeByTypes(['transfer', 'creator'])
print(safeGraph.number_of_nodes(), safeGraph.number_of_edges()) # 55717 199791

# %%
for edge in safeGraph.edges():
    edgeType = safeGraph.edges[edge]
    if not (edgeType['creator'] and edgeType['same_owner'] and edgeType['transfer']):
        safeGraph.remove_edge(edge[0], edge[1])
    else:
        if edgeType['transfer']:
            records = sorted(list(edgeType['transfer-tx_hash']))
            multisigCount = 0
            popularTokenTransferCount = 0
            for r in records:
                if r.startswith('multisig'):
                    multisigCount += 1
                if r.split('_')[-1] in ('ETH', 'USDC', 'USDT', 'WBTC', 'DAI', 'WETH', 'SHIB', 'HEX'):
                    popularTokenTransferCount += 1
            if multisigCount > 5 or popularTokenTransferCount > 3:
                safeGraph.remove_edge(edge[0], edge[1])

print(safeGraph.number_of_nodes(), safeGraph.number_of_edges())
# Out:
# 48778 244

# %%
import networkx as nx
allCcs = [set(cc) for cc in sorted(nx.connected_components(safeGraph), key=len, reverse=True)]

for i in range(len(allCcs)):
    if len(allCcs[i]) >= 2:
        print('# Connected Components {} - {} addresses'.format(i + 1, len(allCcs[i])))
        for addr in allCcs[i]:
            print('\t{}'.format(addr))
        print('\n\n\n\n\n')

for addr in safeGraph.nodes():
    if safeGraph.nodes[addr]['similar_owner']:
        print('# Owners connected in distributeGraph:')
        print('\t{}'.format(addr))
# Out:
# # Connected Components 1 - 29 addresses
# 	0x5969539242892ccf3b2e78437904bd2b0cde684b
# 	0x998ac90e6286b506f22791a0e01978a0aae30b78
# 	0xa022ba0a753fa6b5b725e7bc88b178f5a6c707ab
# 	0x3cd6fff983498df18bad8474554355fafdb63978
# 	0x5b9962a5dbb9953573f793333b61c2237e5bb5a8
# 	0x873d8cfd921062ee62b96ed2ea39cd10f321366b
# 	0xbb390d88be59f9d485617f77cd4d7b8b77bdb6ee
# 	0x99178b08591085666deb185fcd47c0f0b3d0cb43
# 	0x718e4c28e4f3f93a38e65969ecd66dc77fdeabd2
# 	0xeb1063da6f7080eaa0c30356ec6a76cc895ca084
# 	0xff6746e27f1dd7a21134dd7a6740121424daaff8
# 	0x08ef2b3b8540eccc1d04a3022c19ea11af29da5a
# 	0xd6510c2097b93bbd676306c8f59d55579ca56fb1
# 	0x370222d8bed9635d8f97f74813e256fc856c667a
# 	0xdd21df577b00302c44a2f801d85af420a3e154d9
# 	0x53a0035b08da9a27b97bffa7e7be4d917635ae41
# 	0xb92c4d4b53b9d1bbf0f19fc69812c9f9c5900446
# 	0x41890bd02fc108db38e8897296f0454758bdb857
# 	0xdd405d77870f19698ffc3ebb4de18586e02325de
# 	0xd3438ea85fe7a6819aefa1d14fb439ff8280a216
# 	0xf501410d751a7c2536dbc9747e42d37ad0434255
# 	0x07535d4a5e4b39f4ffd47b0fe3dd60db78d66a82
# 	0x01eb674fb11dba2cf8fafc4241f7fb015dacb911
# 	0xafc61227914ae2981398a80b579615b14bd969f6
# 	0xf78197b567ab51ec2d27b3f573406b39afd6e1b3
# 	0xe76d327dd7aaef8eb9c5fca6cf3ee9db58b8efab
# 	0xaec0c9604898bbf5520c806d5c863b3127030960
# 	0x72c551b4f1a70756e3742e6e7146582f6f23757c
# 	0xa3b70d1ffdb7c819930abd4c1188ffd1a6040856
#
#
#
#
#
#
# # Connected Components 2 - 8 addresses
# 	0xfc4b23012c30a71df5d348ff3c42dd01b6490477
# 	0xe68bd81411c349318dad4f345b2838f95a896a5f
# 	0xbb981411754958d3471a0f22ae8eb96417220735
# 	0xfa12cb208cd411f7e09abef3ca4633898e4c2c76
# 	0x87c80f22c352038f230ebc9c2b702339d5e11574
# 	0xd3a322271abccee412ba29bb8a66ac7c8057f785
# 	0x0b7c888c15ff7074c13265af28e46846d7d9e153
# 	0x3de64ce6efc6c113ae5941b1fbcd034f800d2928
#
#
#
#
#
#
# # Connected Components 3 - 7 addresses
# 	0xd7a1ae64dbfac0965ec6132eb6116606e2618110
# 	0x920bb50a256dcb67a84b32064236b396cba4f6aa
# 	0xb9c148dee8802862397577a299a483b34ea0f630
# 	0xcdd08b984b4fa5a53b6380613bf6bb293f1f8edd
# 	0xb3bff6a78d4f95058422761c0eded8c5553d3df9
# 	0x0e60c5094d1fdce1e5227b3333d9d93c1b71deb5
# 	0xe4690b2acc8dda18c27f70098ff929a7d3a4e803
#
#
#
#
#
#
# # Connected Components 4 - 4 addresses
# 	0xb62926ee8f52591c5179ee86cd16970896b6ed47
# 	0xc770506ecc956fcb901562e695da4a6cc5566c2e
# 	0x2cf88b06d4d16f6a03146f5432619a852246ba65
# 	0xe9f2fd3fd87835a68b92fae2173a084d85521d87
#
#
#
#
#
#
# # Connected Components 5 - 3 addresses
# 	0xf53b40dc9c2da0a9198d3cfe8a845c9fff3cd3b7
# 	0x261b183938664935f65ff91a9d74f87c4b2c0513
# 	0xb4c93d4d2de01d8fca2425fae703068792cd5b16
#
#
#
#
#
#
# # Connected Components 6 - 3 addresses
# 	0x4e24f5667b2e482eae1ce561583755f9d67d4c63
# 	0xa20ce1d7f49aa780254e4c3a698eef4831ac0be9
# 	0x7f7a2b7a9c3559a81d51dab1320291260378ce0b
#
#
#
#
#
#
# # Connected Components 7 - 3 addresses
# 	0x8f66b9dac2e4eb07da11dcba76111b4677dbac18
# 	0xa169f07985bbf7d29824e9055ad02a3a0cf4bec2
# 	0xa3128cfe14ce4aee3f812c6c3491892cef62c5b8
#
#
#
#
#
#
# # Connected Components 8 - 3 addresses
# 	0x6a81adc68ea677f053b3207e40416c94140d773b
# 	0xc2404882710364d1b1051e1bfb7ba886a99823f3
# 	0xbda497bb2584b79490cd792d8e6248df38a82eea
#
#
#
#
#
#
# # Connected Components 9 - 3 addresses
# 	0x70496a025eeaeb3f13c8153ed6408e0ba54163fb
# 	0x6b49e6c79e604ea46e1dc8a936bfad4eb97d59e3
# 	0x7abbd44f9b7872fd6db3d54945e94021178477e3
#
#
#
#
#
#
# # Connected Components 10 - 3 addresses
# 	0x8c2fc78172225be98404251de40fc8902c661d87
# 	0xa7796104baafe93f85f6fea50018e835ff08d69a
# 	0x397845246787caf41bb088356120c6ce1f63aa15
#
#
#
#
#
#
# # Connected Components 11 - 3 addresses
# 	0x08517aeb98b9ce9ee873665076f8d4de14a834f2
# 	0xbc231f8fb065f33e2bca7e9654269f0d06933f79
# 	0x8faa3f6ff162c9553ee6731586ea7b463936ecfe
#
#
#
#
#
#
# # Connected Components 12 - 3 addresses
# 	0xd7c281109e3b6f018cc30b31b9803e8f8ce63b96
# 	0xd5ba7b3979280d0d8a02482d06a8f210f45b13ea
# 	0xdc2b2e2576f04ba20b796258d4a92b56c5cca520
#
#
#
#
#
#
# # Connected Components 13 - 3 addresses
# 	0xe5a0e58478fc6f8236a63f4716d601dec293e812
# 	0x0418969d91beb9bc8a8bc54fadc243e3f3723ff5
# 	0x2b8bba0f8f10b37989a2808c31d2be18a7ec3d09
#
#
#
#
#
#
# # Connected Components 14 - 3 addresses
# 	0xe13c163865f68db8101626cf1fdafe4eb55620dd
# 	0xeacfe6cdbf9b9aa4aadf2b075e0609bcc2c31669
# 	0xd5eadf62e7356bf69d9dcb54fe07d2f981835c91
#
#
#
#
#
#
# # Connected Components 15 - 3 addresses
# 	0xee223cf4292ac20533e7a0b81c1d4feed6ecf38c
# 	0xf8a02315a2edf95d28af945264434371fbfd43f8
# 	0xe31f1c4e3b9699b971b7d4e7a8fc4ef0e39a70f9
#
#
#
#
#
#
# # Connected Components 16 - 3 addresses
# 	0xf2001d9e2083a85f8828d831fbeea9b79e515d6b
# 	0xc5cf0ec07ee9b551f11015fd3c127578c098d49b
# 	0x8a09469035f92ee9a8c070786d291cdf165ff6d9
#
#
#
#
#
#
# # Connected Components 17 - 3 addresses
# 	0xeb3d50384ca35624c3e9a86e522eadb4a372ff23
# 	0xe95c569ab66f4ec6863776d3e88204242d660db0
# 	0xeef4f29fd2109fca7e59a39f0a20aa377dc4615a
#
#
#
#
#
#
# # Connected Components 18 - 3 addresses
# 	0x63693b1d60d287c5262e362f78caded66368ea9c
# 	0xc0a1cdfb7df6ef230b718fdf362682a6fcae6cba
# 	0xd6680260f22a17a1bd411dfc1f1d26a0c62f61ae
#
#
#
#
#
#
# # Connected Components 19 - 3 addresses
# 	0x3c88d88239a295253909145af0b85a2b278c628b
# 	0xc573bc83c9067e42d7a6c041812b810b57bc6841
# 	0x748a9eb3a90585c5d448c9432b9ee84fb0c6336f
#
#
#
#
#
#
# # Connected Components 20 - 3 addresses
# 	0xab54a95bf4705d779facfbb3c39fa56e6c24929b
# 	0x1589c316e7910a8ac78956f7018b6ea620fd4bd2
# 	0xbf9117cd602c0a0b38a0bd0eaab80206b2c2b9ef
#
#
#
#
#
#
# # Connected Components 21 - 3 addresses
# 	0xf8877aa690042a43d3152478f7c8e2741257463f
# 	0xaacbeecf96ce2dccb736662882b037d16f00ed6c
# 	0x55665df257644c3b259b770ffbab88250a55640c
#
#
#
#
#
#
# # Connected Components 22 - 3 addresses
# 	0xfed27588535eea65b4254946a717052d5661d5b3
# 	0x0725c16d7e811d03c8c2a64fbbaa579233c10db1
# 	0x355ec66487dffe146c77ae523c72765a6522161f
#
#
#
#
#
#
# # Connected Components 23 - 2 addresses
# 	0x84ad922d23a7613e0d25f36cb65cd5f92a155110
# 	0xe8c1c26b0d86928ae0ad1e7bb3508adb3925cf21
#
#
#
#
#
#
# # Connected Components 24 - 2 addresses
# 	0x57fe7d658c0e23a8812080dc1ce262b4ffa7a2df
# 	0xc1894f02a5e04e0c60561f892f003121a2798169
#
#
#
#
#
#
# # Connected Components 25 - 2 addresses
# 	0x5003915710764012476bb668c3bfe46c93bd2c82
# 	0x93026e9bd83a92ad820a4cbcb212cbf0febe9970
#
#
#
#
#
#
# # Connected Components 26 - 2 addresses
# 	0x7a291314e10eb6f18d7ece2814a36fc9e27ab2cd
# 	0xc7ee29c12d4357843084edbb5f3e95b6e01877c5
#
#
#
#
#
#
# # Connected Components 27 - 2 addresses
# 	0xf6d099d3f7f2e79187fa217b50ef11bd64d94cbd
# 	0x0d9b5595b600c4adb496868d8b71ad77ad718ea2
#
#
#
#
#
#
# # Connected Components 28 - 2 addresses
# 	0x04268ac635b0e26580c6044877aafb0e5d89e7a4
# 	0xa0a52509f25aec9933cae351e19c179049e83b7c
#
#
#
#
#
#
# # Connected Components 29 - 2 addresses
# 	0x09bde89ffcdddc02b60dc8543967aa941f02c0b2
# 	0x43bd4034e84b3bc9c43e9422d8c43f1cc2f8fa63
#
#
#
#
#
#
# # Connected Components 30 - 2 addresses
# 	0x2f9f00edee775f76bd3a94068e5875187dab60ba
# 	0xeb7b3fab31f26c83d4883cd7ba535aaf3cfe0e02
#
#
#
#
#
#
# # Connected Components 31 - 2 addresses
# 	0xecc145d27e18ce43065d60385d54f7a641ed12f6
# 	0xe7e610a18709c60ac010f26b374b77bfa8a0f948
#
#
#
#
#
#
# # Connected Components 32 - 2 addresses
# 	0x370c51b35fbb46ee205dd8df0d27028836f68361
# 	0x96b6f08e24f9ba1adea55fc50734bdbaadb756e9
#
#
#
#
#
#
# # Connected Components 33 - 2 addresses
# 	0xb9df22b7bb430387c88f59b1956864a1219bf5be
# 	0x3ea034f614e746590adc3881255d209da57bbaad
#
#
#
#
#
#
# # Connected Components 34 - 2 addresses
# 	0x9f7cf7a8c3d448a288f968eeeeac21e7eea88ccc
# 	0x310fddcaef27b50782db611cc64fefe0a3b43aa1
#
#
#
#
#
#
# # Connected Components 35 - 2 addresses
# 	0xe09965208e2f35114bbfe65bc8dbca885d07103f
# 	0xcf4b99d03cd764caa496700b9c3aa22f139c87c0
#
#
#
#
#
#
# # Connected Components 36 - 2 addresses
# 	0xdd76360c26eaf63afcf3a8d2c0121f13ae864d57
# 	0x6c4f62b3187bc7e8a8f948bb50abec694719d8d3
#
#
#
#
#
#
# # Connected Components 37 - 2 addresses
# 	0xb639a0edc1e8b17a4f767e774c0da85db0dad14e
# 	0xe3fb6c911c5cce6ca05089d82c0538b2a298c1f1
#
#
#
#
#
#
# # Connected Components 38 - 2 addresses
# 	0x486c4e01228cd81931970b2d79d2efb689717543
# 	0xeec384a40a9a65207aa45afdb0b566e6366afbce
#
#
#
#
#
#
# # Connected Components 39 - 2 addresses
# 	0x00cd63b6a35855c8538293d6289590c21b94356e
# 	0xa0f69483cda62fcdb2852f036a4e0c2f7abafb57
#
#
#
#
#
#
# # Connected Components 40 - 2 addresses
# 	0x54699ee97e55ee239289dd5b34c0b6c18e63f9e8
# 	0x8251f63e8dbca5a36d410f346642b42131a425d9
#
#
#
#
#
#
# # Connected Components 41 - 2 addresses
# 	0x447f47ec9fd19553eef567087c071280f630ca86
# 	0x5c7d903b6023834ab49f3a251f081265f2e9ea18
#
#
#
#
#
#
# # Connected Components 42 - 2 addresses
# 	0x9f5981eb279e2e35e4d40f5b1a56199033f6ed71
# 	0x8fd0802e5ee89bac92f976351f7ee2426cb517c1
#
#
#
#
#
#
# # Connected Components 43 - 2 addresses
# 	0xfa2f494d3de0bcade722d93ceeb607a100c07c14
# 	0xa93859b1df637e878f10f6dfdeb67c35ce8fff9c
#
#
#
#
#
#
# # Connected Components 44 - 2 addresses
# 	0xae15681cee3d942c0bbea70db721fd9f8a6c4a5d
# 	0x08665a3acc8d152bb8b25db341c5e8309de205e7
#
#
#
#
#
#
# # Connected Components 45 - 2 addresses
# 	0xb6b1357fb903c997bc42fc00ac69d769bff466b2
# 	0xec9db76e5551a6cec0df9fb153087e67a2c04023
#
#
#
#
#
#
# # Connected Components 46 - 2 addresses
# 	0xfa1fdb69da9c535a2b0f65dfc593cd7143d33d24
# 	0x512851f212755f2b9117b6ed0943acd98680c173
#
#
#
#
#
#
# # Connected Components 47 - 2 addresses
# 	0xfce2a698e31b376612008eca1361edb025346be7
# 	0xfd69337986c904bc09d312c133613ceaf2d53ac5
#
#
#
#
#
#
# # Connected Components 48 - 2 addresses
# 	0xd1d278b80ca73e380f6a758672610ce0f442c6f5
# 	0x12457b7f162efc487a8fb9f3b81a7c0b909ac35a
#
#
#
#
#
#
# # Connected Components 49 - 2 addresses
# 	0x6bc568adec8a41d63ba171c45915e2dfc9c1c198
# 	0x81a17e70b728fe99df00672a14ada95aa1b934dd
#
#
#
#
#
#
# # Connected Components 50 - 2 addresses
# 	0x6bfc8a57d678d22c274419d47416b200d04d5fb9
# 	0x63de3808ca7968abb8065b35e77530e3608576e0
#
#
#
#
#
#
# # Connected Components 51 - 2 addresses
# 	0x3c877b6eb0c28b7a0d37f7b4de2814a7679d11cf
# 	0xa3478ba1973ea057493adf67c87d6cf00d385978
#
#
#
#
#
#
# # Connected Components 52 - 2 addresses
# 	0x462a4bbf0975db7b297c231e06e01f4771680da6
# 	0xc286041403a81a76224899d989c11734897408f6
#
#
#
#
#
#
# # Connected Components 53 - 2 addresses
# 	0xdb5f92db961cf31c4079622d464679fb899a7cb9
# 	0x2c7b032d04cefd6fb910a27ccf0d8913c4fa16a8
#
#
#
#
#
#
# # Connected Components 54 - 2 addresses
# 	0xa8d369a1f833b95b1f97a866eda31dc4261b1b42
# 	0x3e4cb3a22bc78853bef740df8cad6c4039d1a517
#
#
#
#
#
#
# # Connected Components 55 - 2 addresses
# 	0x98453192c444d99bd2a5923cc102e38192a03de5
# 	0x4e50f7a87399e956e399eea81c811cd04ced09f2
#
#
#
#
#
#
# # Connected Components 56 - 2 addresses
# 	0xd0d5742dfc2fc353e1f73961fbc6d30a82cb77fc
# 	0xeb6355857b68e1fd375cb22eafebcdb1486bc62a
#
#
#
#
#
#
# # Connected Components 57 - 2 addresses
# 	0x494d0c43c10b31e50f9edfc8cc6241de55da86ee
# 	0x33d86914b5cecccdbd9d7eb2fc9e37279a43da62
#
#
#
#
#
#
# # Connected Components 58 - 2 addresses
# 	0xe657e2708974687477db81f76234ac8efbff1aca
# 	0x4e497f7fa20438353ea43d9441140f7944994769
#
#
#
#
#
#
# # Connected Components 59 - 2 addresses
# 	0x0c333d48af19c2b42577f3c8f4779f0347f8c819
# 	0xebed45ca22fcf70adccab7618c51a3dbb06c8d83
#
#
#
#
#
#
# # Connected Components 60 - 2 addresses
# 	0x8004d366b3219f4674987a9133e416151d8828dd
# 	0x9105953a37b82449ed79fe74c0c905a25f75dfe2
#
#
#
#
#
#
# # Connected Components 61 - 2 addresses
# 	0x9b6f6fd780d690dc041e8d2b23bd3c1e2d72b136
# 	0xa9090bc767e2313e5b32d1fbf3251f57ebae633b
#
#
#
#
#
#
# # Connected Components 62 - 2 addresses
# 	0x5bf318975c33f1a472a010c0e7ccf688a9f470b6
# 	0xe44c0d0b2d1e7e818fee960a6dbd9a4b1fa40871
#
#
#
#
#
#
# # Connected Components 63 - 2 addresses
# 	0x5ba4b082e7474d1a814bc8baed0f1c5f8607723b
# 	0x72d29f1f1a469db84237d4dea7b3c15a2900ca25
#
#
#
#
#
#
# # Connected Components 64 - 2 addresses
# 	0x3f31344c9b8628f809b1c4f53505958b8b6418a1
# 	0x3a88ba9aa6ab7d1b52e75ff5739a60cf100ee336
#
#
#
#
#
#
# # Connected Components 65 - 2 addresses
# 	0x34e5b09e4da536e9e90af96fcb178c78c2671460
# 	0x3f62ac1a5d25f7c1f94c293d6421a91badf74681
#
#
#
#
#
#
# # Connected Components 66 - 2 addresses
# 	0xc5878bb056f6391dbca5ddee1986ebcae234549b
# 	0x88f1412a3bbb4cde458e16e9d919d2e2c044e259
#
#
#
#
#
#
# # Connected Components 67 - 2 addresses
# 	0x382c3db5f61b581ecfea3446bbd18909001a551d
# 	0xdc3ae2611dd77985ea71985f99922f7b2303c010
#
#
#
#
#
#
# # Connected Components 68 - 2 addresses
# 	0x83592c4894d063d08a0b4f0b2c3d2d8669fe2fc4
# 	0x5abfcfd7feadb9a618af1b50a1b72047fbbb7774
#
#
#
#
#
#
# # Connected Components 69 - 2 addresses
# 	0x9cb023fcfdb538ba349f370b84b4304c7b34a38e
# 	0x9764a6ce32c7b9ee230c352ef52195bd382bc8a4
#
#
#
#
#
#
# # Connected Components 70 - 2 addresses
# 	0xa30cee946e572bf7ad273d988bad6a958901b8ba
# 	0x95790d1f3946b5c8bc62d21f6a1503548ab0f510
#
#
#
#
#
#
# # Connected Components 71 - 2 addresses
# 	0xb9cda042a5ab5bd59ee400478e8de5b336bd8e53
# 	0xb1fe31fc073ca1b6a0919fa96aca62f93a269355
#
#
#
#
#
#
# # Connected Components 72 - 2 addresses
# 	0xeeb1841ccc3b9218b5fb0ff580f838388cf6bd5b
# 	0xda0ae1f5b580cb6d58b0a1c6acde2ab06793a6e2
#
#
#
#
#
#
# # Connected Components 73 - 2 addresses
# 	0x34ecff6049ff90ef9c178d16ec53e794f44e93f4
# 	0xeb4b579161d160859d55bc4d17b7416f397bbaa0
#
#
#
#
#
#
# # Connected Components 74 - 2 addresses
# 	0xa2a2e289c964dbf1203c5f475eece3ebea44ce6f
# 	0xefe906e6b73dd64ad3f80afb7c83bd9c4c188709
#
#
#
#
#
#
# # Connected Components 75 - 2 addresses
# 	0x4508b7f9d18e730f03fcd041c5002bd14d30101c
# 	0x602f434fca9b7d4a98218c3afab93255c696df2f
#
#
#
#
#
#
# # Connected Components 76 - 2 addresses
# 	0x25c9fc75f4cdc0a8a7ff6122ae235023df1820e9
# 	0x910077a9e5ccdfa70001167de42ae9abfbebb18f
#
#
#
#
#
#
# # Connected Components 77 - 2 addresses
# 	0x30faa70225b60b7b89d27e4e3cc36cc6ebd60ea1
# 	0xceceacd9e301178e55f25c32b5f426c564efe91b
#
#
#
#
#
#
# # Connected Components 78 - 2 addresses
# 	0x3db4befc59573c635da71e4863fa5d6f3e3acaf0
# 	0x9fa42b6fd94ed23c8a42969d83961a569fe4cf4f
#
#
#
#
#
#
# # Connected Components 79 - 2 addresses
# 	0x979dc077a590381f99dec276b639cb99984ceec6
# 	0x59d772394118e0241a4b441bd4243230de816065
#
#
#
#
#
#
# # Connected Components 80 - 2 addresses
# 	0xb07cbe99d20f8f78a16b879a2b4ce1cb6bc6c3bd
# 	0x55ae8f00b3f0497b5d4b0723bfd9566a2b27a45e
#
#
#
#
#
#
# # Connected Components 81 - 2 addresses
# 	0x7301201dc91b4888ef84c4c96012546d5d880af9
# 	0x9c94e442bc7c6aaa3d467393d4e10c33b547d456
#
#
#
#
#
#
# # Connected Components 82 - 2 addresses
# 	0x849ce09190f6d4087b227dba3921460a9665bf5a
# 	0xdd5f0efee3c01b760515c301c1178c15ee94ea85
#
#
#
#
#
#
# # Connected Components 83 - 2 addresses
# 	0xf3a995d9808ec42bfdb72ca1b514ce170394393d
# 	0x9df104fa06712aea02ae0c49027dd7230b1a7b4f
#
#
#
#
#
#
# # Connected Components 84 - 2 addresses
# 	0xea327547614de474e6c3fe2b2e343756abca7ee0
# 	0xa1b34e5054e1b46e317f6aac0646180e5b41fa7d
#
#
#
#
#
#
# # Connected Components 85 - 2 addresses
# 	0xddab73b5e199076a78576615b2ef8f78133ff2c3
# 	0x1265b817a4eec4bf57c8f8fbabc2db96ffc0d5e7
#
#
#
#
#
#
# # Connected Components 86 - 2 addresses
# 	0xc02cf9ff9035163c403be75381ea7d4fc4dbf70e
# 	0xbae5db1e3dd2d8d2a52d7aee401d9cb99a6b0c5b
#
#
#
#
#
#
# # Connected Components 87 - 2 addresses
# 	0x30880a9a3ce286a75bf709b107c269a6036fc229
# 	0xcd333fc4d5e281795fa1c5ba1cb593368a3bf6d9
#
#
#
#
#
#
# # Connected Components 88 - 2 addresses
# 	0xe9c0b08e878592d8ad3e4fc84a69f994a611b455
# 	0x47695bd561fe20eb4dce8c8a84bfa7588b4cc2cb
#
#
#
#
#
#
# # Connected Components 89 - 2 addresses
# 	0x1b47e0d0a8e2de5f286c5e99c96117f9081f268d
# 	0x981a9ff7dc3b1513e098a8911a998d7827cc8be4
#
#
#
#
#
#
# # Connected Components 90 - 2 addresses
# 	0x4442bd78f16c1b071aba01e7e035c98efab6e6bf
# 	0x45ebffac88220d6933572b6b8921ce4bc6908da0
#
#
#
#
#
#
# # Connected Components 91 - 2 addresses
# 	0xe2e03f3e4fd2d52e1d5e59402466362b1df176f6
# 	0xcdac562a5c535089ed9f6377d4c8cef301fb35f2
#
#
#
#
#
#
# # Connected Components 92 - 2 addresses
# 	0x5a63814f7dd015c3c2ef038aee19b0079dc62f30
# 	0xd07df2054dfa094351dbe1aacfe59a8760750ed9
#
#
#
#
#
#
# # Connected Components 93 - 2 addresses
# 	0xa7180f8111bcd00b33aec52129737e69255671f0
# 	0xb27cf4bfd0507f1dfc6ebce4a24900f77d028726
#
#
#
#
#
#
# # Connected Components 94 - 2 addresses
# 	0x465b126cb3507edca4c37ff2d581fbb05ec7fade
# 	0xe6f83737e04a12626572b9032136dfe77fa739c9
#
#
#
#
#
#
# # Connected Components 95 - 2 addresses
# 	0x9490167933fdbbcd7aa5b6b66f79e2ea42ddd6fb
# 	0xbd7cd83ad7b9b37ec83d2761f1924ef6c71ccc11
#
#
#
#
#
#
# # Connected Components 96 - 2 addresses
# 	0xda0bcf7b319d2db7e6f3bbed5b8595ade356db62
# 	0x11bc807eb31e49fe171a32f8346095eb00008a59
#
#
#
#
#
#
# # Connected Components 97 - 2 addresses
# 	0xaa6b0ea9e304be0cb6dc36aba0721dc9768b2804
# 	0x6bf96fd7346b408f6c657cb5c385dbd9e7f35d5f
#
#
#
#
#
#
# # Connected Components 98 - 2 addresses
# 	0x3c8e59f37ad510863801db42a18761908f2f5409
# 	0x40c85a54c7b3feb9eedebf4b6f054df3c167d701
#
#
#
#
#
#
# # Connected Components 99 - 2 addresses
# 	0x3dce374636f7cc72a1387197193248e634b046f1
# 	0xe69790a7dd29e716ef8e176a2a254ec631bc7a78
#
#
#
#
#
#
# # Connected Components 100 - 2 addresses
# 	0x2302ae210995cad93edb630a3de0319c03fe5d57
# 	0x91e6f1208ab7c630a210a29c6668760dc5896727
#
#
#
#
#
#
# # Connected Components 101 - 2 addresses
# 	0xd33a2d10b797b6ad6692476174c7d1bf4d1bbdb1
# 	0xdea00bf933bec332913cc3d8562fe590ea1c9800
#
#
#
#
#
#
# # Connected Components 102 - 2 addresses
# 	0xf2b90b29a96d63d3ee731c6ce876aa613519491e
# 	0x5be5307c199ed1fa0f853b4a8ae85118c3ac6906
#
#
#
#
#
#
# # Connected Components 103 - 2 addresses
# 	0xa47604e6a747b8cdff7749a128b52227263d838a
# 	0x09b2beb31befba61eec4661ecbebfe259b4f77bc
#
#
#
#
#
#
# # Connected Components 104 - 2 addresses
# 	0xcdaace71ea8f2f280294e7de4c6dc875781ab023
# 	0x192c5fe7eb4f0629e20276a5ba48835c980fd348
#
#
#
#
#
#
# # Connected Components 105 - 2 addresses
# 	0x2aa99771aadf77b425b410e8c5d4f1695a94e6b2
# 	0xf3a15c4bbc332824b10282b5d0cceadb06a72518
#
#
#
#
#
#
# # Connected Components 106 - 2 addresses
# 	0x03dbb3dd462e4d6f0b59e7033ed0670a0d9b54ee
# 	0x50c5aa97523cb0c0827d24ca74947337a1f73c7e
#
#
#
#
#
#
# # Connected Components 107 - 2 addresses
# 	0xebe26c2e41bae0c53ee4d0980736cf4c8ea6bdb1
# 	0x8f894e37c511970d92be09db7fe949898d2fd7ad
#
#
#
#
#
#
# # Connected Components 108 - 2 addresses
# 	0xd30e5a4eb777b52cabcabaa70ffe10c9e0d7c2cf
# 	0xcdf9af41a3e0863a5b9cdce555bb4d23a2ce8cdb
#
#
#
#
#
#
# # Connected Components 109 - 2 addresses
# 	0x2a6ad44fb74366f8890129366450599143d0e647
# 	0xc62f1c0a7cb27d5ab162943e1ea679b5a0819ec5
#
#
#
#
#
#
# # Connected Components 110 - 2 addresses
# 	0x3c962603fea7162236631fc8ffb9b4f48016c89d
# 	0xf32db904d58cfa503b8c688952d5fd9af64b236e
#
#
#
#
#
#
# # Connected Components 111 - 2 addresses
# 	0xd52c38c297f6d6ccd60d566a8d61f3dd28e26e91
# 	0xd03078756f74ee044dcec42fea37eb6c97f53755
#
#
#
#
#
#
# # Connected Components 112 - 2 addresses
# 	0xcf6f758c63c7409564b1b4632dc2d28acf1b47f7
# 	0xdab7633871caa6e081f9c9d0ba8985deb07ffc34
#
#
#
#
#
#
# # Connected Components 113 - 2 addresses
# 	0xeadc720cfb4f7e3244fb446349b68c18f9832d2d
# 	0xc54e5e24e263bdea161239c1229fd838002afe5a
#
#
#
#
#
#
# # Connected Components 114 - 2 addresses
# 	0x0d7fac32e447bb24e37ddc6f15ec5f5ba83d8be9
# 	0xaea9fcf3230d8e43d3694e3d93748b77e48cf199
#
#
#
#
#
#
# # Connected Components 115 - 2 addresses
# 	0x85ed0e04a1878439cf2159767476beda4aceecf8
# 	0x5039c7f3a02ce4c9dadc5b129a02d690254512cd
#
#
#
#
#
#
# # Connected Components 116 - 2 addresses
# 	0xb178408fcdd532849a4e0fdd63bc6f7225a44aa5
# 	0x3133eecf9ef368c2cceb55a3493ab9f8db4066b7
#
#
#
#
#
#
# # Connected Components 117 - 2 addresses
# 	0x8cfc6431512a22b41f12d0ade7feae54ecd46104
# 	0xdad974cbe4553dfab3940f03aac7edeeacf377cb
#
#
#
#
#
#
# # Connected Components 118 - 2 addresses
# 	0x1556a43afa006a96a15e08e98e31f4c98854e56e
# 	0x2c562cb512cd29533777e258b9182a8dc0e3da8e
#
#
#
#
#
#
# # Connected Components 119 - 2 addresses
# 	0x8bbdf82ad7e6bba715316ace25a8b1bef64f9327
# 	0x67b39e7bdc8ce1ec4a7786b49e2af5da178f5b68
#
#
#
#
#
#
# # Connected Components 120 - 2 addresses
# 	0x8a6a09703253bdea6dbe1ceda99db2cb1e6a349e
# 	0xa9329dbbea43e7b7a219e9c7f959e65b8cf3a6f3
#
#
#
#
#
#
# # Connected Components 121 - 2 addresses
# 	0x37c9a75a10d8d6d92f18bb85f25432b090971e5d
# 	0xfc4006e3cb9b29ff5f0990dbfb2a0b688aba1474
#
#
#
#
#
#
# # Connected Components 122 - 2 addresses
# 	0x74e5a67998260470ac9fb67230f41b86d2975111
# 	0x6c4a88de7f7d22afc5e5ca68fd273fa883683a6f
#
#
#
#
#
#
# # Connected Components 123 - 2 addresses
# 	0x2b3dd79e2a8369c8750f8d116c891e4e397cbb4b
# 	0xf5dd51efc45c73673660fa217b3366d8d8ba2ed2
#
#
#
#
#
#
# # Connected Components 124 - 2 addresses
# 	0xfe9cde4ac9e17c6a0e6040a88134699f032f4bea
# 	0xc695f81ad281a86b7eae2046b786eb69f7fafa28
#
#
#
#
#
#
# # Connected Components 125 - 2 addresses
# 	0x3d4e1aa3c6f7fc0498f16333e6e6b0641b13d3ef
# 	0xed52f41ca6877eda9b33b6d76a9eb36ffcd72b50
#
#
#
#
#
#
# # Connected Components 126 - 2 addresses
# 	0xf24dc8eda3cde523e933886e3b568864e315cd3d
# 	0x311f58e172a7fe55295802ab43e826f7d26606e8
#
#
#
#
#
#
# # Connected Components 127 - 2 addresses
# 	0xdd924e4156df09522e05c0083f5706788507a994
# 	0x34ab14f591f059b9546829b41c635d529f99b86d
#
#
#
#
#
#
# # Connected Components 128 - 2 addresses
# 	0x528fb768c4ece411242d5984f533b412b0aa50c7
# 	0xd97accbd8cffd6bf612e3ed8cbf776393bd26306
#
#
#
#
#
#
# # Connected Components 129 - 2 addresses
# 	0x38dd0740a3e956b10d3c3eefb734cead84e694ce
# 	0x95456b16dbde0fe06ed47b7164deeb161de55654
#
#
#
#
#
#
# # Connected Components 130 - 2 addresses
# 	0x675c86f06c923ce025ed90d57324915a0f8e7f5a
# 	0x76224d2799a12021829fdb6164a04d0c5475ab77
#
#
#
#
#
#
# # Connected Components 131 - 2 addresses
# 	0x884972c11cfde35b4860903db89d0545c924f453
# 	0xe8707e23485c0b6d4aed242a08ba0d373470a349
#
#
#
#
#
#
# # Connected Components 132 - 2 addresses
# 	0xaef390987ef01129311ced79f6e44b889be045e9
# 	0x15908632892f2de63c932624fdde4badd93c8c57
#
#
#
#
#
#
# # Connected Components 133 - 2 addresses
# 	0xd4858e1f5498f2bc89a7caa1a47616c009545be7
# 	0xbd442b04d1705b8583054acbb94e4e46dbbfbd70
#
#
#
#
#
#
# # Connected Components 134 - 2 addresses
# 	0x0745a55bda2988952a94f6b7f3503a13b096bee9
# 	0xff51d2f36743e59a9016a2ffbfcf66ec61fdeca2
#
#
#
#
#
#
# # Connected Components 135 - 2 addresses
# 	0xc79dcdc33f74147e06e3715a2604b22a93b7bb1a
# 	0x5ea5f5034cbfe49494610d526fe6410fb0954b7d
#
#
#
#
#
#
# # Connected Components 136 - 2 addresses
# 	0x56f2642c1cdc7a15a7d1d591f2f977adc1169bfe
# 	0x55346ba17cd2ff8a2785743e4be38c71182432b1
#
#
#
#
#
#
# # Connected Components 137 - 2 addresses
# 	0x447c2a525af56c103b9731a9c1e0cea1239b0609
# 	0x603112e6dc2f416c8c22735f0caaff77a6bd9e16
#
#
#
#
#
#
# # Connected Components 138 - 2 addresses
# 	0xea4125109e4452a1088fcbbd5634c9f43282a504
# 	0x599e97a7397005a64d8021f4a92bc988ee0be30d
#
#
#
#
#
#
# # Owners connected in distributeGraph:
# 	0x91e34ba9fe3dec87dcc8d9f11657161d51f1b827
# # Owners connected in distributeGraph:
# 	0x83b89b861ec1ca12b4efa3845a39987bb3511999

# %%
# get all evidences between addr1 and addr2

import networkx as nx
from collections.abc import Iterable

def checkEvidence(graph, addr1, addr2): 
    assert addr1 in graph.nodes(), addr1
    assert addr2 in graph.nodes(), addr2
    if (addr1, addr2) in graph.edges:
        edgeInfo = graph.edges[addr1, addr2]
        for k, v in edgeInfo.items():
            print('"{}"'.format(k))
            if isinstance(v, Iterable):
                v = sorted(list(v))
                for element in v:
                    print('\t{}'.format(element))
            else:
                print('\t{}'.format(v))
    else:
        all_shortest_paths = [p for p in nx.all_shortest_paths(graph, source=addr1, target=addr2)]
        for p in all_shortest_paths:
            print(p)

addr1 = '0x6b49e6c79e604ea46e1dc8a936bfad4eb97d59e3'
addr2 = '0x70496a025eeaeb3f13c8153ed6408e0ba54163fb'
graph = safeGraph
checkEvidence(graph, addr1, addr2)
# Out:
# "same_owner"
# 	True
# "creator"
# 	True
# "creator-tx_hash"
# 	0xabf83c8c2be67a5fd670da5bb23ac1f287f0d95451f8795f266c0fabc2970064
# 	0xd016b1963bce583998a8b2be795415211516856b2a49c4a7e2e49cecbd5d986b
# "transfer"
# 	True
# "transfer-tx_hash"
# 	0x716dc8e944018d02eecb0ce3b0a859b69d9628f74622c92d73eb1c3be40dfd7d_USDT
# 	multisig_0x6B49e6C79e604EA46E1DC8A936bFaD4Eb97D59E3_0xfefd77e047ba39845e2009f2833ab6177a93f2cd9cbb95965c809c16cb37680e_USDT
# "similar_owner"
# 	False
# "distributeEth"
# 	False
